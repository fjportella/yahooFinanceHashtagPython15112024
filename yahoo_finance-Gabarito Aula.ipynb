# %% [markdown]
# ### Pegar Cotações do Yahoo Finance com Python
#
# - pandas_datareader
# - yfinance

# %%
import pandas as pd
import pandas_datareader.data as pdr
import yfinance

yfinance.pdr_override()

# %%
ativos = ["ITUB3.SA", "VALE3.SA", "PETR3.SA", "^BVSP"]

data_inicial = "2023-01-01"
data_final = "2023-06-30"

tabela_cotacoes = pdr.get_data_yahoo(ativos, data_inicial, data_final)["Adj Close"]
display(tabela_cotacoes)
# Out:
# [*********************100%***********************]  4 of 4 completed
#              ITUB3.SA   PETR3.SA   VALE3.SA     ^BVSP
# Date
# 2023-01-02  20.825558  22.264847  87.478874  106376.0
# 2023-01-03  20.427494  21.950058  87.322311  104166.0
# 2023-01-04  20.446911  22.315893  87.478874  105334.0
# 2023-01-05  21.048862  23.039053  88.946640  107518.0
# 2023-01-06  21.320711  22.894421  90.355698  108836.0
# ...               ...        ...        ...       ...
# 2023-06-23  24.674603  33.900002  65.900002  118977.0
# 2023-06-26  24.604704  34.560001  66.040001  118243.0
# 2023-06-27  24.434948  34.259998  66.830002  117523.0
# 2023-06-28  24.255207  34.509998  64.720001  116681.0
# 2023-06-29  24.444933  34.889999  65.510002  118383.0
#
# [123 rows x 4 columns]
